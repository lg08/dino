# %% [markdown]
# <a href="https://colab.research.google.com/github/lg08/dino/blob/main/Sample_Evaluation_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python run_training.py \
 --input_file sts-smoothing_1.jsonl \
 --output_dir output
# Out:
# Parameters: Namespace(input_file='sts-smoothing_1.jsonl', output_dir='output', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='03/05/2023 14:46:47')
# 100% 392k/392k [00:00<00:00, 687kB/s]
# ...
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
# !pip install tensorrt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tensorrt: filename=tensorrt-8.6.1-py2.py3-none-any.whl size=16983 sha256=59d50593078d395a2f8d7176bf152bde499a608c844bb6712c2d431a11d283ff
#   Stored in directory: /root/.cache/pip/wheels/6d/29/56/abdffd4c604f255b5254bef3f1c598ab7811ea020540599438
# Successfully built tensorrt
# ...

# %%
# !python run_training.py \
 --input_file sts-smoothing_2.jsonl \
 --output_dir output_2
# Out:
# Parameters: Namespace(input_file='sts-smoothing_2.jsonl', output_dir='output_2', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='03/05/2023 15:20:05')
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-05-03 15:20:10 - Use pytorch device: cuda
# ...

# %%
# !python run_training.py \
 --input_file sts-smoothing_5.jsonl \
 --output_dir output5
# Out:
# Parameters: Namespace(input_file='sts-smoothing_5.jsonl', output_dir='output5', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='03/05/2023 15:49:00')
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-05-03 15:49:05 - Use pytorch device: cuda
# ...

# %%
# !python postprocess_dataset.py \
 --input_file sts-raw.jsonl \
 --output_file sts-smoothing_0.jsonl

# %%
# !python run_training.py \
 --input_file sts-smoothing_0.jsonl \
 --output_dir output0
# Out:
# Parameters: Namespace(input_file='sts-smoothing_0.jsonl', output_dir='output0', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='03/05/2023 16:21:26')
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-05-03 16:21:31 - Use pytorch device: cuda
# ...

# %%
# !python postprocess_dataset.py \
--input_file sts-raw.jsonl \
--output_file sts-aug_0.jsonl

# %%
# !python run_training.py \
 --input_file sts-aug_0.jsonl \
 --output_dir output_a0
# Out:
# Parameters: Namespace(input_file='sts-aug_0.jsonl', output_dir='output_a0', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='03/05/2023 16:53:17')
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-05-03 16:53:22 - Use pytorch device: cuda
# ...

# %%
# !python run_training.py \
 --input_file sts-smoothing_3.jsonl \
 --output_dir output3
# Out:
# Parameters: Namespace(input_file='sts-smoothing_3.jsonl', output_dir='output3', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='04/05/2023 00:35:00')
# 100% 392k/392k [00:00<00:00, 887kB/s]
# ...
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
# !python run_training.py \
 --input_file sts-smoothing_4.jsonl \
 --output_dir output4
# Out:
# Parameters: Namespace(input_file='sts-smoothing_4.jsonl', output_dir='output4', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='04/05/2023 01:02:54')
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-05-04 01:02:57 - Use pytorch device: cuda
# ...

# %%
# !python run_training.py \
 --input_file sts-aug_1.jsonl \
 --output_dir output_a1
# Out:
# Parameters: Namespace(input_file='sts-aug_1.jsonl', output_dir='output_a1', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='04/05/2023 01:30:28')
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-05-04 01:30:32 - Use pytorch device: cuda
# ...

# %%
# !python run_training.py \
 --input_file sts-aug_3.jsonl \
 --output_dir output_a3
# Out:
# Parameters: Namespace(input_file='sts-aug_3.jsonl', output_dir='output_a3', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='04/05/2023 01:43:10')
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-05-04 01:43:12 - Use pytorch device: cuda
# ...

# %%
# !python postprocess_dataset.py \
 --input_file sts-raw-x1x2.jsonl \
 --output_file sts-smoothing_x1x2_3.jsonl

# %%
# !python run_training.py \
 --input_file sts-smoothing_x1x2_2.jsonl \
 --output_dir output_x1x2_2
# Out:
# Parameters: Namespace(input_file='sts-smoothing_x1x2_2.jsonl', output_dir='output_x1x2_2', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='04/05/2023 04:24:15')
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-05-04 04:24:16 - Use pytorch device: cuda
# ...

# %%
# !python run_training.py \
 --input_file sts-smoothing_x1x2_1.jsonl \
 --output_dir output_x1x2_1
# Out:
# Parameters: Namespace(input_file='sts-smoothing_x1x2_1.jsonl', output_dir='output_x1x2_1', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='04/05/2023 05:19:07')
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-05-04 05:19:09 - Use pytorch device: cuda
# ...

# %%
# !python postprocess_dataset.py \
 --input_file sts-raw-x1x2.jsonl \
 --output_file sts-x1x2-aug_0.jsonl

# %%
# !python run_training.py \
 --input_file sts-x1x2-aug_0.jsonl \
 --output_dir output_x1x2_aug_0
# Out:
# Parameters: Namespace(input_file='sts-x1x2-aug_0.jsonl', output_dir='output_x1x2_aug_0', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='04/05/2023 18:40:53')
# 100% 392k/392k [00:00<00:00, 1.17MB/s]
# ...
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
# !python postprocess_dataset.py \
 --input_file sts-raw-x1x2.jsonl \
 --output_file sts-x1x2-aug_1.jsonl

# %%
# !python run_training.py \
 --input_file sts-x1x2-aug_1.jsonl \
 --output_dir output_x1x2_aug_1
# Out:
# Parameters: Namespace(input_file='sts-x1x2-aug_1.jsonl', output_dir='output_x1x2_aug_1', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='04/05/2023 19:06:45')
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-05-04 19:06:49 - Use pytorch device: cuda
# ...

# %%
# !python postprocess_dataset.py \
 --input_file sts-raw-x1x2.jsonl \
 --output_file sts-x1x2-aug_3.jsonl

# %%
# !python run_training.py \
 --input_file sts-x1x2-aug_3.jsonl \
 --output_dir output_x1x2_aug_3
# Out:
# Parameters: Namespace(input_file='sts-x1x2-aug_3.jsonl', output_dir='output_x1x2_aug_3', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='04/05/2023 19:43:21')
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-05-04 19:43:23 - Use pytorch device: cuda
# ...

# %%
# !python postprocess_dataset.py \
 --input_file sts-x2-dataset.jsonl \
 --output_file test_aug_label.jsonl

# %%
# !python run_training.py \
 --input_file test_aug_label.jsonl \
 --output_dir output_test
# Out:
# Parameters: Namespace(input_file='test_aug_label.jsonl', output_dir='output_test', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='04/05/2023 21:33:22')
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-05-04 21:33:24 - Use pytorch device: cuda
# ...

# %%
# !python postprocess_dataset.py \
 --input_file sts-x2-decay-dataset.jsonl \
 --output_file decay.jsonl

# %%
# !python run_training.py \
 --input_file decay.jsonl \
 --output_dir decay
# Out:
# Parameters: Namespace(input_file='decay.jsonl', output_dir='decay', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='04/05/2023 22:38:49')
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-05-04 22:38:51 - Use pytorch device: cuda
# ...

# %%
# !python postprocess_dataset.py \
 --input_file sts-x2-decay-dataset.jsonl \
 --output_file decay_small.jsonl

# %%
# !python run_training.py \
 --input_file decay_small.jsonl \
 --output_dir decay_small
# Out:
# Parameters: Namespace(input_file='decay_small.jsonl', output_dir='decay_small', model_name='roberta-base', train_batch_size=32, num_epochs=1, seed=42, sts_dataset_path='datasets/stsbenchmark.tsv.gz', date='04/05/2023 23:12:11')
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2023-05-04 23:12:14 - Use pytorch device: cuda
# ...
